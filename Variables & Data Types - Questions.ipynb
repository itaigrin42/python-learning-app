# %% [markdown]
# # Variables & Data Types
# © Advanced Analytics, Amir Ben Haim, 2024

# %% [markdown]
# ## Execise 1

# %% [markdown]
# In the code cell below, use the <code>print()</code> function to print out the phrase: <code>Hello, world!</code>

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
# Out:
# Hello, world!

# %% [markdown]
# ## Execise 2

# %% [markdown]
# In the code cell below, print out the phrase: <code>Hello, world!</code> and comment it with the phrase <code>Print the traditional hello world</code> all in one line of code

# %%
print("Hello, world!") #Print the traditional hello world
# Out:
# Hello, world!

# %%
# Out:
# Hello, world!

# %% [markdown]
# ## Execise 3

# %% [markdown]
# In the code cell below, use the <code>type()</code> function to check the object type of <code>12.0</code>

# %%
type(12.0)
# Out:
# float

# %%
# Out:
# float

# %% [markdown]
# ## Execise 4

# %% [markdown]
# What is the data type of the result of: <code>6 / 2</code>?

# %%
type(6/2)
# Out:
# float

# %%
# Out:
# float

# %% [markdown]
# ## Execise 5

# %% [markdown]
# What is the type of the result of: <code>6 // 2</code>? (Note the double slash <code>//</code>.)

# %%
type(6//2)
# Out:
# int

# %% [markdown]
# ## Execise 6

# %% [markdown]
# Let's write an expression that calculates how many hours there are in 160 minutes:

# %%
a=160/60
a
# Out:
# 2.6666666666666665

# %%
# Out:
# 2.6666666666666665

# %% [markdown]
# ## Execise 7

# %% [markdown]
# Format the result above to only 2 decimal numbers

# %%
f'{a:.2f}'
# Out:
# '2.67'

# %%
# Out:
# '2.67'

# %% [markdown]
# ## Execise 8

# %% [markdown]
# What is the value of <code>x</code> where <code>x = 3 + 2 * 2</code>

# %%
x=3+2*2
x
# Out:
# 7

# %%
# Out:
# 7

# %% [markdown]
# ## Execise 9

# %% [markdown]
# What is the value of <code>y</code> where <code>y = (3 + 2) * 2</code>?

# %%
y=(3+2)*2
y
# Out:
# 10

# %%
# Out:
# 10

# %% [markdown]
# ## Execise 10

# %%
z=x+y
z
# Out:
# 17

# %% [markdown]
# What is the value of <code>z</code> where <code>z = x + y</code>?

# %%
# Out:
# 17

# %% [markdown]
# ## Execise 11

# %% [markdown]
# What is the value of the variable <code>A = "1"</code>?

# %%
A="1"
A
# Out:
# '1'

# %%
# Out:
# '1'

# %% [markdown]
# ## Execise 12

# %% [markdown]
# What is the value of the variable <code>B = 2</code>?

# %%
B=2
B
# Out:
# 2

# %%
# Out:
# 2

# %% [markdown]
# ## Execise 13

# %% [markdown]
# Use the variables <code>A</code> and <code>B</code> to create <code>12</code> (as an int!)

# %%
int(A+str(B))
# Out:
# 12

# %%
# Out:
# 12

# %% [markdown]
# ## Execise 14

# %% [markdown]
# Consider the variable <code>D = "ABCDEFG"</code> use slicing to print out the first three elements:

# %%
D = "ABCDEFG"
D[0:3]
# Out:
# 'ABC'

# %%
# Out:
# ABC

# %% [markdown]
# ## Execise 15

# %% [markdown]
# Use a stride value of 2 to print out every second character of the string <code>E = 'clocrkr1e1c1t'</code>:

# %%
E = 'clocrkr1e1c1t'
E[0::2]
# Out:
# 'correct'

# %%
# Out:
# correct

# %% [markdown]
# ## Execise 16

# %% [markdown]
# Print out a backslash:

# %%
print('\\')
# Out:
# \

# %% [markdown]
# ## Execise 17

# %% [markdown]
# Convert the variable <code>F = "You are wrong"</code> to uppercase:

# %%
F = "You are wrong"
F.upper()
# Out:
# 'YOU ARE WRONG'

# %%
# Out:
# YOU ARE WRONG

# %% [markdown]
# ## Execise 18

# %% [markdown]
# Consider the variable <code>G</code>, and find the first index of the sub-string <code>snow</code>:
# ```python
# G = '''Mary had a little lamb Little lamb, little lamb Mary had a little lamb
# Its fleece was white as snow And everywhere that Mary went Mary went, Mary went
# Everywhere that Mary went The lamb was sure to go'''
# ```

# %%
G = '''Mary had a little lamb Little lamb, little lamb Mary had a little lamb
Its fleece was white as snow And everywhere that Mary went Mary went, Mary went
Everywhere that Mary went The lamb was sure to go'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 4
#       1 G = '''Mary had a little lamb Little lamb, little lamb Mary had a little lamb
#       2 Its fleece was white as snow And everywhere that Mary went Mary went, Mary went
#       3 Everywhere that Mary went The lamb was sure to go'''
# ----> 4 G.find(snow)
#
# NameError: name 'snow' is not defined

# %%
# Out:
# 95

# %% [markdown]
# ## Execise 19

# %% [markdown]
# In the variable <code>G</code>, replace the sub-string <code>Mary</code> with <code>Bob</code>:

# %%
# Out:
# 'Bob had a little lamb Little lamb, little lamb Bob had a little lamb\nIts fleece was white as snow And everywhere that Bob went Bob went, Bob went\nEverywhere that Bob went The lamb was sure to go'

# %% [markdown]
# ## Execise 20

# %% [markdown]
# Create a string variable `s` containing the word `"Ha"`. Multiply this string by `10` and assign it to a variable named `laugh`. Print `laugh`.

# %%
# Out:
# HaHaHaHaHaHaHaHaHaHa

# %% [markdown]
# ## Execise 21

# %% [markdown]
# Given the string `phrase = "Data Science with Python"`, extract the substrings `"Data"`, `"Science"`, and `"Python"`. Concatenate them into a new string separated by hyphens (`-`) and assign it to a variable named `new_phrase`. Print `new_phrase`.

# %%
# Out:
# Data-Science-Python

# %% [markdown]
# ## Execise 22

# %% [markdown]
# Assign `True` to variables `p` and `q`. Compute the logical expression `not p or q` and assign the result to a variable named `result`. Print `result`.

# %%
# Out:
# True

# %% [markdown]
# ## Execise 23

# %% [markdown]
# String Formatting with f-Strings
#
# Given the variables `name = "Bob"` and `balance = 53.44`, use an f-string to print the sentence:
#
# "Hello Bob, your current balance is $53.44."

# %%
# Out:
# Hello Bob, your current balance is $53.44.

# %% [markdown]
# ## Execise 24

# %% [markdown]
# Using String Methods
#
# Given the string `text = "   Hello, World!   "`, remove the leading and trailing whitespace, convert it to uppercase, and replace the exclamation mark with a period. Assign the final string to a variable named `modified_text` and print it.

# %%
# Out:
# HELLO, WORLD.

# %% [markdown]
# ## Execise 25

# %% [markdown]
# Advanced String Formatting
#
# Format the number `number = 1234567.8910` to include commas as thousands separators and display two decimal places. Assign the formatted string to a variable named `formatted_number` and print it.

# %%
# Out:
# 1,234,567.89
