# %%
import random

print("WELCOME TO 'Which Num'!")
print('')
print("I'm thinking of a number between 1 and 100")
print("If your FIRST guess is more than 10 away from my number, I'll tell you you're COLD")
print("If your guess FIRST is within 10 of my number, I'll tell you you're WARM")

print("If your next guesses is farther than your most recent guess, I'll say you're getting COLDER")
print("If your next guesses is closer than your most recent guess, I'll say you're getting WARMER")
print("LET'S PLAY!")
print('')



#num = random.randint(1,100)
num=56
guesses = []
# Out:
# WELCOME TO 'Which Num'!
#
# I'm thinking of a number between 1 and 100
# If your FIRST guess is more than 10 away from my number, I'll tell you you're COLD
# If your guess FIRST is within 10 of my number, I'll tell you you're WARM
# If your next guesses is farther than your most recent guess, I'll say you're getting COLDER
# If your next guesses is closer than your most recent guess, I'll say you're getting WARMER
# LET'S PLAY!

# %%
import random

num = random.randint(1,100)
guesses = []

while True:
    g = int(input('give me num'))
    if not(1<=g<=100):
        print("not in the range")
        continue
    elif g==num:
        print(f'congarts u did it in {len(guesses)+1} guesses')
        break
    guesses.append(g)
       
    if len(guesses)==1:
        if abs(g-num)<=10:
            print('Warm')
        else:
            print("Cold")
    else: 
        if abs(g-num)<=abs(guesses[-2]-num):
            print('Warmer!')
        else:
            print('Colder!')
# Out:
# give me num 50
# Cold
# give me num 80
# Colder!
# give me num 60
# Warmer!
# give me num 40
# Warmer!
# give me num 30
# Warmer!
# give me num 20
# Warmer!
# give me num 10
# Warmer!
# give me num 5
# Warmer!
# give me num 1
# Colder!
# give me num 4
# congarts u did it in 10 guesses

# %%
abs(guesses[-1]-num)
# Out:
# 55

# %%
guesses[-1]
# Out:
# 1

# %%
print(guesses)
# Out:
# [44, 55, 90, 54, 90, 99, 1]
