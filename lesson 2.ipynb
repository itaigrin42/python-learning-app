# %%
a=[1, 2, 3.5, 'ABC', False]
a
# Out:
# [1, 2, 3.5, 'ABC', False]

# %%
a=[1,2,3]
b=[7,8,9]
print(a)
print(b)
# Out:
# [1, 2, 3]
# [7, 8, 9]

# %%
a+b
# Out:
# [1, 2, 3, 7, 8, 9]

# %%
a.extend([b])
a
# Out:
# [1, 2, 3, 'b', [7, 8, 9]]

# %%
a.pop()
a
# Out:
# [1, 2, 3, 'b']

# %%
a={1,2,2,3,4,4,4}
a
# Out:
# {1, 2, 3, 4}

# %%
a
# Out:
# [1, 2, 3]

# %%
b=a.copy()
b
# Out:
# [1, 2, 3]

# %%
id(b)
id(a)
# Out:
# 2140421390016

# %%
id(a)
# Out:
# 2140421390016

# %%
b=list(a)

# %%
b
# Out:
# [1, 2, 3]

# %%
id(b)
# Out:
# 2140421357120

# %%
d={1:'AAA',2:'BBB',4:'CCC'}
d
# Out:
# {1: 'AAA', 2: 'BBB', 4: 'CCC'}

# %%
type(d)
# Out:
# dict

# %%
d.pop(3,'foo')
# Out:
# 'foo'

# %%
d
# Out:
# {1: 'AAA', 2: 'BBB', 4: 'CCC'}

# %%
f=(1,)
type(f)
# Out:
# tuple
