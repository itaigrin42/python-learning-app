# %% [markdown]
# # Matplotlib Exercise

# %% [markdown]
# © Advanced Analytics, Amir Ben Haim, 2024

# %% [markdown]
# <br></br>
# ### <code>plt.text()</code>

# %% [markdown]
# <br></br>
# Introducing <code>plt.text()</code> to help with the next exercise
# <br>
# <br>
# <code>plt.text()</code> helps to add lables to data points
# <br>
# <br>
# Syntax:
# <br>
# <code>plt.text(x=x coordinate, y=y coordinate, s=string to be displayed)</code>
# <br></br>

# %% [markdown]
# Let's start by importing `Matplotlib` and `Matplotlib.pyplot` as follows:

# %%
import matplotlib.pyplot as plt

# %%
# Example
a = [1,10, 20]
b = [3, 30, 10]

plt.plot(a,b)

plt.text(10,21, 'starts \nto \ndecrease -->')

plt.show()

# %% [markdown]
# <br></br>
# x and y values in `plt.text(x, y, label)`:
#
#     Since 'a' list elements are type 'integer', we can specify the value 10 for x-axis.
# ```python
#     plt.text(10,21, 'starts \nto \ndecrease -->') # Data stored as type int
# ```
# <br></br>
#
#     If the elements were stored as type 'string', we would need to specify x as the index position.
#     Eg index 1.
# ```python
#     plt.text(1,21, 'starts \nto \ndecrease -->') # Data stored as type string
# ```
#
# <br></br>

# %%
# Example
a = ['1','10', '20']
b = [3, 30, 10]

plt.plot(a,b)

plt.text(1,21, 'starts \nto \ndecrease -->')

plt.show()

# %% [markdown]
# <br></br>
# ### Exercise 1

# %% [markdown]
# Concidere the folowing Data points below, And create a 2-d <u><b>scatter</b></u> plot as folows
# <br></br>
# add data labels for <b><u>Y axis only</u></b> using `plt.text()`
# </br>
#
# ```python
# x = [500, 354, 264, 231,  660, 561,  300, 297, 305, 363, 396, 297, 198]
# y = [3267, 2838, 2871, 2904, 3663, 2838, 3399, 2871, 3102, 2574, 2541, 2805, 2838]
# ```

# %%
x = [500, 354, 264, 231,  660, 561,  300, 297, 305, 363, 396, 297, 198]
y = [3267, 2838, 2871, 2904, 3663, 2838, 3399, 2871, 3102, 2574, 2541, 2805, 2838]
plt.plot(x, y, 'o', color='#C1D9ED', markeredgecolor='#8FAABD', markersize=10)
for i in range(len(x)):
    plt.text(x[i],y[i]+15, f'{y[i]}')
plt.show()

# %% [markdown]
# <br></br>
# ### Exercise 2

# %% [markdown]
# Note that the highest point (the one labeld 3663) jutting out of the figure area, fix it using `plt.xlim`, `plt.ylim` methods

# %%
x = [500, 354, 264, 231,  660, 561,  300, 297, 305, 363, 396, 297, 198]
y = [3267, 2838, 2871, 2904, 3663, 2838, 3399, 2871, 3102, 2574, 2541, 2805, 2838]
plt.plot(x, y, 'o', color='#C1D9ED', markeredgecolor='#8FAABD', markersize=10)
for i in range(len(x)):
    plt.text(x[i],y[i]+15, f'{y[i]}')
plt.xlim(100,720)
plt.ylim(2300,3900)
plt.show()

# %% [markdown]
# <br></br>
# ### Exercise 3

# %% [markdown]
# Try to add Background Box with param `bbox`

# %%
x = [500, 354, 264, 231,  660, 561,  300, 297, 305, 363, 396, 297, 198]
y = [3267, 2838, 2871, 2904, 3663, 2838, 3399, 2871, 3102, 2574, 2541, 2805, 2838]
plt.plot(x, y, 'o', color='#C1D9ED', markeredgecolor='#8FAABD', markersize=10)
for i in range(len(x)):
    plt.text(x[i],y[i]+27, f'{y[i]}', fontsize=7, color='red',bbox=dict(facecolor='yellow', edgecolor='gray', alpha=0.5, boxstyle='square',pad=0.6))
plt.xlim(100,720)
plt.ylim(2300,3900)
plt.show()
